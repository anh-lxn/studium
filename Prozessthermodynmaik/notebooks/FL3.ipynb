# %% [markdown]
# # FL.3 Gebäudeklimatisierung (muss noch gemacht werden)

# %%
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(os.path.join(project_root, "src"))
# %load_ext autoreload
# %autoreload 2
from coolprop_utils import get_saturation_properties
from FL import *
