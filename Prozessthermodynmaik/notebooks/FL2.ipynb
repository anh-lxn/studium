# %% [markdown]
# # FL.2 Kurbehandlungsraum

# %%
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(os.path.join(project_root, "src"))
# %load_ext autoreload
# %autoreload 2
from coolprop_utils import get_saturation_properties
from FL import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Tzu = 32 # °C
phizu = 0.35
mLzu = 0.13 # kg/s
Tw = 38 # °C
mW = 0.67 / 1000 # kg/s
Qzu = 1.9 # kW
Qab = 3.0 # kW
p = 100000 # Pa

# %% [markdown]
# a)

# %%
pszu = get_saturation_properties(T=Tzu, return_value="ps") # Pa
xzu = eq45x(p, pszu, phizu) # kgW/kgL
hzu = eq410h(Tzu, xzu)

hw = get_saturation_properties(T=Tw, return_value="h''") # kJ/kg

hr = ((Qzu - Qab)+(mLzu*hzu+mW*hw))/mLzu # kJ/kg
xr = xzu + (mW/mLzu)

Tr = eq410T(hr, xr)
Tr
# Out:
# 23.825537035359705

# %%
psr = get_saturation_properties(T=Tr, return_value="ps") # Pa
phir = eq45phi(p, psr, xr)
phir
# Out:
# 0.8327864687629404
