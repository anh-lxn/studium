# %% [markdown]
# # Technische Strömungsmechanik
# ## Nachbereitungsfragen – Vorlesung 02: Wirbelströmungen

# %% [markdown]
# 1. Wann ist eine Strömung zweidimensional?
#
# - Alle geschwindigkeitskomponenten sind unabhängig von der dritten Raumrichtung, und die dritte Geschwindigkeitskomponente ist null.

# %% [markdown]
# 2. Welche Eigenschaft kennzeichnet eine orthonormale Basis? Formulieren Sie die Ba-
# sisvektoren für kartesische Koordinaten und für Zylinderkoordinaten
#
# - Orthonormale Basisvektoren sind Einheitsvektoren, die Senkrecht auf einander stehen.
#
# - Kartesische Koordinaten: ex, ey, ez
#
# - Zylinderkoordinaten: er, eθ, et mi er=(cosθ, sinθ, 0), eθ=(-sinθ, cosθ, 0), ez=(0,0,1)

# %% [markdown]
# 3. Skizzieren Sie das Geschwindigkeitsfeld eines Wirbels mit Starrk¨orperrotation in ei-
# nem kartesischen Koordinatensystem. Formulieren Sie anschließend den Geschwin-
# digkeitsvektor u sowohl in kartesischen Koordinaten als auch in Zylinderkoordinaten
# und berechnen Sie zus¨atzlich jeweils die Wirbelst¨arke ω
#
# ![Skizze](img/v02_03.png)

# %% [markdown]
# 4. Wie ist eine Stromlinie definiert? Warum verlaufen die Stromlinien eines
# Starrkörperwirbels kreisförmig?
#
# - Kurve, deren Tangente überall mit dem Geschwindigkeitsvektor übereinstimmt.
# - Beim Starrkörperwirbel gibt es nur tangentiale Geschwindigkeitskomponenten, daher verlaufen die Stromlinien kreisförmig.

# %% [markdown]
# 5. Welchen charakteristischen Verlauf besitzen bei einem Starrk¨orperwirbel die Um-
# fangsgeschwindigkeit uθ und der Betrag der Wirbelst¨arke ‖ω‖ ¨uber den Radius?
# Nutzen Sie eine Skizze zur Veranschaulichung
#
# ![Skizze](img/v02_05.png)

# %% [markdown]
# 6. Geben Sie das Geschwindigkeitsfeld u eines Potentialwirbels sowohl in kartesischen
# Koordinaten als auch in Zylinderkoordinaten an und berechnen Sie anschließend die
# Wirbelst¨arke ω.
#
# - Kartesische Koordinaten:
# $$
# \underline{u} = \frac{\Gamma}{2 \pi r^2} \begin{pmatrix} -y \\ x \\ 0 \end{pmatrix} ,
# r = \sqrt{x^2 + y^2}
# $$
#
# - Zylinderkoordinaten:
# $$
# \underline{u} = \frac{\Gamma}{2 \pi r} \underline{e}_{\theta}
# $$
# </details>
#
# - Wirbelstärke:
# $$
# \underline{\omega} = \nabla \times \underline{u} = 0
# $$
#
# ![Diagramme](img/v02_06.png)

# %% [markdown]
# 7. Wie verhält sich bei einem Potentialwirbel die Umfangsgeschwindigkeit uθ und der
# Betrag der Wirbelstärke ‖ω‖ in Abhängigkeit vom Radius? Skizzieren und charakterisieren Sie jeweils den Funktionsverlauf. Welche Besonderheit ist außerdem bei r = 0 zu beachten?
#
# - Je größer der Radius desto geringer die Umfangsgeschwindigkeit.
# - Die Wirbelstärke ist überall null außer bei r=0, wo sie eine Singularität aufweist, da die Geschwindigkeit dort unendlich wird.

# %% [markdown]
# 8. Vergleichen Sie einen Starrk¨orperwirbel mit einem Potentialwirbel hinsichtlich des
# Verlaufs der Umfangsgeschwindigkeit f¨ur r → ∞ und r → 0.
#
# - für r → ∞:
# Starrkörperwirbel: uθ → ∞, Potentialwirbel: uθ → 0
#
# - für r → 0:
# Starrkörperwirbel: uθ → 0, Potentialwirbel: uθ → ∞

# %% [markdown]
# 9. In welchen Bereichen wird ein Rankine-Wirbel durch einen Starrk¨orperwirbel bzw.
# durch einen Potentialwirbel beschrieben? Skizzieren Sie dazu den Verlauf der Um-
# fangsgeschwindigkeit uθ und der Zirkulation Γ in Abh¨angigkeit vom Radius. Wo ist
# die Str¨omung rotationsbehaftet?
#
# ![Skizze](img/v02_09.png)

# %% [markdown]
# 10. Welche Parameter m¨ussen zur eindeutigen Beschreibung eines Rankine-Wirbels an-
# gegeben werden?
#
# - Kernradius r0 und Zirkulation Γ oder Wirbelstärke ω

# %% [markdown]
# 11. Inwiefern kann ein Potentialwirbel als Grenzfall eines Rankine-Wirbels angesehen
# werden?
#
# - für r0 → 0 wird der Rankine-Wirbel zum Potentialwirbel,

# %% [markdown]
# 12. Wie unterscheidet sich ein echter Tornado vom Modell des Rankine-Wirbels?
#
# ![Echter Tornado vs. Rankine-Wirbel](img/v02_12.png)

# %% [markdown]
# 13. Nennen Sie unter Angabe des Geschwindigkeitsvektors u und des Wirbelst¨arkevek-
# tors ω mindestens zwei Beispiele f¨ur die Aussage, dass nicht alle rotationsbehafte-
# ten Str¨omungen zugleich auch Wirbel darstellen. Welche Eigenschaft eines Wirbels
# erf¨ullen die genannten Str¨omungen nicht?
#
#
# ![Beispiele](img/v02_13.png)
# - Fehlende Eigenschaft: umlaufende/kreisende Stromlinien um eine Achse (keine Wirbelkerne).

# %% [markdown]
# 14. Welche zwei Aspekte bei der Berechnung der Zirkulation Γ beeinflussen grunds¨atz-
# lich ihren Wert?
#
# - Wahl der Integrationskurve und ihr Orientierung
# - Geschwindigkeitsfeld entlang der Kurve

# %% [markdown]
# 15. Wie ist der Zusammenhang zwischen der Zirkulation Γ und der Wirbelst¨arke ω
# definiert?
#
# $$
# \Gamma = \oint_S \underline{u} \cdot d\underline{s} = \int_A \underline{\omega} \cdot \underline{n} \, dA
# $$

# %% [markdown]
# 16. Formulieren Sie in Worten, wie die Zirkulation Γ
#
# - Linienintegral: Tangentialgeschwindigkeit entlang des geschlossenen Weges aufsummieren.
#
# - Stokes: Fluss der Wirbelstärke durch eine von C aufgespannte Fläche berechnen (Normale beachten)

# %% [markdown]
# 17. Welches Problem ergibt sich bei der Berechnung der Zirkulation Γ entlang einer
# Kreisbahn um das Zentrum eines Potentialwirbels, wenn der Stokessche Integral-
# satz verwendet wird? Wie kann mithilfe des Rankine-Wirbels das Problem in eine
# Grenzfallbetrachtung umformuliert werden?
#
#
# - Beim Potentialwirben ist die Wirbelsträke gleich 0. Dadurch würde die Zirkulation mit Stokes Theorem immer 0 ergeben.
# - Lösung: Rankine Grenzfall mit r0 → 0 betrachten, da hier die Wirbelstärke im Kern ungleich 0 ist.

# %% [markdown]
# 18. Welche Eigenschaft besitzt die Zirkulation Γ entlang einer geschlossenen Kurve f¨ur
# die beiden F¨alle, dass das Zentrum eines Potentialwirbels umlaufen bzw. nicht um-
# laufen wird? Nutzen Sie eine Skizze zur Veranschaulichung.
#
# - Kurve umschließt das Zentrum ⇒ Γ=konstant=Γ0.
# - Kurve umschließt nicht ⇒ Γ=0. (Skizze: Kreis um Zentrum vs. Kreis daneben.)

# %% [markdown]
# 19. Wovon h¨angt der Wert der Zirkulation Γ entlang einer geschlossenen Kurve in einem
# gegebenen Geschwindigkeitsfeld u eines Potentialwirbels lediglich ab? Was ist die
# Ursache daf¨ur?
#
# - nur davon ob Kurve das Zentrum des Wirbels umschließt oder nicht. Ursache ist die Singularität der Wirbelstärke am Zentrum.

# %% [markdown]
# 20. Das Zentrum eines Potentialwirbels wird von zwei Kreisbahnen mit Radius R1 = R
# und R2 = 2R umlaufen. In welcher Beziehung stehen die Zirkulationen Γ1 und Γ2
# der beiden Kreisbahnen zueinander?
#
# - Γ1 = Γ2
